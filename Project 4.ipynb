# %% [markdown]
# Technology Lookup Data Cleaning

# %% [markdown]
# # Project 4

# %% [markdown]
# Dataset(JSON):"https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json"

# %% [markdown]
# Categories="https://raw.githubusercontent.com/AliasIO/wappalyzer/master/src/technologies.json"

# %%
#Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
tech=pd.read_json("https://raw.githubusercontent.com/sahilrahman12/Technology-Lookup-Web-Application/main/technologies.json")

# %%
data=df.copy()

# %%
data
# Out:
#                                                      1C-Bitrix  \
# cats                                                    [1, 6]
# description  1C-Bitrix is a system of web project managemen...
# headers      {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# html         (?:<link[^>]+components/bitrix|(?:src|href)="/...
# icon                                             1C-Bitrix.svg
# implies                                                    PHP
# scripts                                              1c-bitrix
# website                                http://www.1c-bitrix.ru
# cookies                                                    NaN
# js                                                         NaN
# dom                                                        NaN
# pricing                                                    NaN
# saas                                                       NaN
# meta                                                       NaN
# ...

# %%
#1. Manipulate the Dataframe in such a way that the column becomes the ro and vice-versa

# %%
data=data.T   #<- This T will transpose the data

# %%
data
# Out:
#               cats                                        description  \
# 1C-Bitrix   [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart      [1, 6]                                                NaN
# @sulu/web     [59]                                                NaN
# A-Frame       [25]                                                NaN
# A8.net        [71]          A8.net is an affiliate marketing network.
# ...            ...                                                ...
# wisyCMS        [1]                                                NaN
# wpBakery      [51]  WPBakery is a drag and drop visual page builde...
# wpCache       [23]  WPCache is a static caching plugin for WordPress.
# xCharts       [25]                                                NaN
# xtCommerce     [6]                                                NaN
#
#                                                       headers  \
# 1C-Bitrix   {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# ...

# %%
data.head()
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
# A-Frame      [25]                                                NaN
# A8.net       [71]          A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1511 entries, 1C-Bitrix to xtCommerce
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cats         1511 non-null   object
#  1   description  776 non-null    object
#  2   headers      320 non-null    object
#  3   html         428 non-null    object
#  4   icon         1474 non-null   object
#  5   implies      482 non-null    object
#  6   scripts      679 non-null    object
#  7   website      1511 non-null   object
#  8   cookies      146 non-null    object
#  9   js           600 non-null    object
#  10  dom          60 non-null     object
#  11  pricing      213 non-null    object
#  12  saas         204 non-null    object
#  13  meta         272 non-null    object
#  14  cpe          195 non-null    object
#  15  certIssuer   5 non-null      object
#  16  url          51 non-null     object
#  17  oss          31 non-null     object
# ...

# %%
data.shape    #<-here, The row values are as same as cat values. It means there is no null values in cats column
# Out:
# (1511, 21)

# %%
cats=pd.read_json("https://raw.githubusercontent.com/AliasIO/wappalyzer/master/src/technologies.json")

# %%
cats
# Out:
#                    $schema                                    categories  \
# 1           ../schema.json                {'name': 'CMS', 'priority': 1}
# 2           ../schema.json     {'name': 'Message boards', 'priority': 1}
# 3           ../schema.json  {'name': 'Database managers', 'priority': 2}
# 4           ../schema.json      {'name': 'Documentation', 'priority': 2}
# 5           ../schema.json            {'name': 'Widgets', 'priority': 9}
# ...                    ...                                           ...
# wisyCMS     ../schema.json                                           NaN
# wpBakery    ../schema.json                                           NaN
# wpCache     ../schema.json                                           NaN
# xCharts     ../schema.json                                           NaN
# xtCommerce  ../schema.json                                           NaN
#
#                                                  technologies
# ...

# %%
data_cats=cats.copy()

# %%
data_tech=tech.copy()

# %%
data_tech=data_tech.T

# %%
data_tech.head()
# Out:
#              cats                                        description  \
# 1C-Bitrix  [1, 6]  1C-Bitrix is a system of web project managemen...
# 3dCart     [1, 6]                                                NaN
# @sulu/web    [59]                                                NaN
# A-Frame      [25]                                                NaN
# A8.net       [71]          A8.net is an affiliate marketing network.
#
#                                                      headers  \
# 1C-Bitrix  {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                            {'X-Powered-By': '3DCART'}
# @sulu/web                                                NaN
# A-Frame                                                  NaN
# A8.net                                                   NaN
#
#                                                         html           icon  \
# 1C-Bitrix  (?:<link[^>]+components/bitrix|(?:src|href)="/...  1C-Bitrix.svg
# ...

# %%
data_cats
# Out:
#                    $schema                                    categories  \
# 1           ../schema.json                {'name': 'CMS', 'priority': 1}
# 2           ../schema.json     {'name': 'Message boards', 'priority': 1}
# 3           ../schema.json  {'name': 'Database managers', 'priority': 2}
# 4           ../schema.json      {'name': 'Documentation', 'priority': 2}
# 5           ../schema.json            {'name': 'Widgets', 'priority': 9}
# ...                    ...                                           ...
# wisyCMS     ../schema.json                                           NaN
# wpBakery    ../schema.json                                           NaN
# wpCache     ../schema.json                                           NaN
# xCharts     ../schema.json                                           NaN
# xtCommerce  ../schema.json                                           NaN
#
#                                                  technologies
# ...

# %%
data_tech.cats
# Out:
# 1C-Bitrix     [1, 6]
# 3dCart        [1, 6]
# @sulu/web       [59]
# A-Frame         [25]
# A8.net          [71]
#                ...
# wisyCMS          [1]
# wpBakery        [51]
# wpCache         [23]
# xCharts         [25]
# xtCommerce       [6]
# Name: cats, Length: 1511, dtype: object

# %%
for i in data_tech.cats:
    print(i)
# Out:
# [1, 6]
# [1, 6]
# [59]
# [25]
# [71]
# [74]
# [10]
# [10]
# [12]
# [1, 5]
# [22]
# [59]
# [10]
# [10]
# [6]
# [71]
# [70]
# [10]
# [6]
# [71]
# [68]
# [6, 72]
# [62]
# [32]
# [36]
# [36]
# [36]
# [36]
# [68]
# [36]
# [5, 10]
# [5]
# [5]
# [3]
# [36]
# [10]
# [18]
# [42]
# [1]
# [10]
# [42]
# [20]
# [4]
# [32, 74]
# [18]
# [10]
# [36]
# [36]
# [41]
# [36]
# [11]
# [71, 36]
# [71]
# [6]
# [6]
# [41]
# [10]
# [32]
# [52]
# [31]
# [19]
# [32, 10]
# [31]
# [16]
# [16]
# [10, 47]
# [55]
# [18, 22]
# [29]
# [54]
# [22]
# [12]
# [12]
# [20]
# [65]
# [71]
# [31]
# [22]
# [63]
# [65]
# [41]
# [19]
# [75]
# [62]
# [6]
# [18, 22]
# [41]
# [1]
# [41]
# [1]
# [10]
# [10]
# [36]
# [12]
# [66]
# [18]
# [12]
# [12]
# [22]
# [8]
# [22]
# [22]
# [18]
# [51]
# [4]
# [41]
# [59]
# [1]
# [10]
# [36]
# [62]
# [41]
# [69]
# [72]
# [6]
# [1]
# [35]
# [47]
# [22]
# [31]
# [1, 20, 27]
# [14]
# [29]
# [47]
# [8]
# [47]
# [13]
# [13, 47]
# [13, 62]
# [68]
# [12]
# [19]
# [19]
# [62]
# [32, 74, 75]
# [6]
# [5]
# ...

# %%
for i in data_tech.cats:
    for j in range(len(i)):
        print(i[j])
# Out:
# 1
# 6
# 1
# 6
# 59
# 25
# 71
# 74
# 10
# 10
# 12
# 1
# 5
# 22
# 59
# 10
# 10
# 6
# 71
# 70
# 10
# 6
# 71
# 68
# 6
# 72
# 62
# 32
# 36
# 36
# 36
# 36
# 68
# 36
# 5
# 10
# 5
# 5
# 3
# 36
# 10
# 18
# 42
# 1
# 10
# 42
# 20
# 4
# 32
# 74
# 18
# 10
# 36
# 36
# 41
# 36
# 11
# 71
# 36
# 71
# 6
# 6
# 41
# 10
# 32
# 52
# 31
# 19
# 32
# 10
# 31
# 16
# 16
# 10
# 47
# 55
# 18
# 22
# 29
# 54
# 22
# 12
# 12
# 20
# 65
# 71
# 31
# 22
# 63
# 65
# 41
# 19
# 75
# 62
# 6
# 18
# 22
# 41
# 1
# 41
# 1
# 10
# 10
# 36
# 12
# 66
# 18
# 12
# 12
# 22
# 8
# 22
# 22
# 18
# 51
# 4
# 41
# 59
# 1
# 10
# 36
# 62
# 41
# 69
# 72
# 6
# 1
# 35
# 47
# 22
# 31
# 1
# 20
# 27
# 14
# 29
# 47
# 8
# 47
# 13
# 13
# 47
# 13
# 62
# 68
# 12
# 19
# 19
# 62
# 32
# 74
# 75
# 6
# 5
# 32
# 75
# 29
# 59
# 31
# 62
# 31
# 12
# 1
# 1
# 19
# 3
# 9
# 12
# 1
# 10
# 1
# 18
# 6
# 6
# 6
# 3
# 6
# 32
# 5
# 36
# 6
# 41
# 32
# 18
# 22
# 18
# 7
# 6
# 14
# 11
# 1
# 29
# 10
# 32
# 74
# 32
# 75
# 20
# 59
# 25
# 52
# 1
# 11
# 1
# 18
# 5
# 72
# 5
# 72
# 5
# ...

# %%
for i in data_tech.cats:
    for j in range(len(i)):
        i[j]=data_cats.categories.iloc[i[j]-1]["name"]

# %%
data_tech
# Out:
#                              cats  \
# 1C-Bitrix        [CMS, Ecommerce]
# 3dCart           [CMS, Ecommerce]
# @sulu/web                  [PaaS]
# A-Frame     [JavaScript graphics]
# A8.net              [A/B Testing]
# ...                           ...
# wisyCMS                     [CMS]
# wpBakery                    [CRM]
# wpCache                 [Caching]
# xCharts     [JavaScript graphics]
# xtCommerce            [Ecommerce]
#
#                                                   description  \
# 1C-Bitrix   1C-Bitrix is a system of web project managemen...
# 3dCart                                                    NaN
# @sulu/web                                                 NaN
# A-Frame                                                   NaN
# A8.net              A8.net is an affiliate marketing network.
# ...                                                       ...
# wisyCMS                                                   NaN
# ...

# %%
data_tech["description"]
# Out:
# 1C-Bitrix     1C-Bitrix is a system of web project managemen...
# 3dCart                                                      NaN
# @sulu/web                                                   NaN
# A-Frame                                                     NaN
# A8.net                A8.net is an affiliate marketing network.
#                                     ...
# wisyCMS                                                     NaN
# wpBakery      WPBakery is a drag and drop visual page builde...
# wpCache       WPCache is a static caching plugin for WordPress.
# xCharts                                                     NaN
# xtCommerce                                                  NaN
# Name: description, Length: 1511, dtype: object

# %%
#It shows how many null values inside the column
data_tech.description.isna().sum()
# Out:
# 735

# %%
data_tech.headers.isna().sum()  #<- It shows how many null values inside the header column
# Out:
# 1191

# %%
data_tech.headers.notnull().sum()  #<-It shows how many not null values inside the header column
# Out:
# 320

# %%
data_tech.headers
# Out:
# 1C-Bitrix     {'Set-Cookie': 'BITRIX_', 'X-Powered-CMS': 'Bi...
# 3dCart                               {'X-Powered-By': '3DCART'}
# @sulu/web                                                   NaN
# A-Frame                                                     NaN
# A8.net                                                      NaN
#                                     ...
# wisyCMS                                                     NaN
# wpBakery                                                    NaN
# wpCache       {'X-Powered-By': 'wpCache(?:/([\d.]+))?\;versi...
# xCharts                                                     NaN
# xtCommerce                                                  NaN
# Name: headers, Length: 1511, dtype: object

# %%
# Find all the unique values from data_tech.headers dictionary
arr=[]
for i in range(len(data_tech.headers)):
    if pd.notnull(data_tech.headers[i]):
       arr.extend(list(data_tech.headers[i].keys()))   #<- This extend will add every list elements as single one by one

# %%
arr
# Out:
# ['Set-Cookie',
#  'X-Powered-CMS',
#  'X-Powered-By',
#  'Server',
#  'X-AH-Environment',
#  'X-Advertising-By',
#  'Cookie',
#  'X-Powered-By',
#  'X-Powered-By',
#  'Server',
#  'X-Akamai-Transformed',
#  'X-EdgeConnect-MidMile-RTT',
#  'X-EdgeConnect-Origin-MEX-Latency',
#  'X-Akaunting',
#  'Server',
#  'Server',
#  'Via',
#  'X-Amz-Cf-Id',
#  'Server',
#  'Server',
#  'server',
#  'X-Powered-By',
#  'Server',
#  'Server',
#  'X-Powered-By',
#  'Server',
#  'X-Powered-By',
#  'Arastta',
#  'X-Arastta',
#  'Server',
#  'AR-PoweredBy',
#  'X-Confluence-Request-Time',
#  'X-StatusPage-Skip-Logging',
#  'X-StatusPage-Version',
#  'X-Hacker',
#  'Server',
#  'azure-regionname',
#  'azure-sitename',
#  'azure-slotname',
#  'azure-version',
#  'X-EC-Debug',
#  'server',
#  'X-Supplied-By',
#  'X-Backdrop-Cache',
#  'X-Generator',
#  'X-Powered-By',
#  'CMS-Version',
#  'X-Powered-By',
#  'x-bubble-capacity-limit',
#  'x-bubble-capacity-used',
#  'x-bubble-perf',
#  'Server',
# ...

# %%
arr=set(arr)

# %%
arr
# Out:
# {'AR-PoweredBy',
#  'Access-Control-Allow-Headers',
#  'Arastta',
#  'CMS-Version',
#  'COMMERCE-SERVER-SOFTWARE',
#  'Composed-By',
#  'Content-Type',
#  'Cookie',
#  'DNNOutputCache',
#  'Derak-Umbrage',
#  'Expires',
#  'Fastly-Debug-Digest',
#  'IBM-Web2-Location',
#  'Itx-Generated-Timestamp',
#  'Liferay-Portal',
#  'Link',
#  'MicrosoftSharePointTeamServices',
#  'OracleCommerceCloud-Version',
#  'Powered-By',
#  'SPRequestGuid',
#  'Server',
#  'Servlet-engine',
#  'Set-Cookie',
#  'SharePointHealthScore',
#  'Vary',
#  'Via',
#  'WP-Super-Cache',
#  'WebDevSrc',
#  'Weglot-Translated',
#  'X-AH-Environment',
#  'X-ATG-Version',
#  'X-Advertising-By',
#  'X-Akamai-Transformed',
#  'X-Akaunting',
#  'X-Amz-Cf-Id',
#  'X-Application-Context',
#  'X-Arastta',
#  'X-AspNet-Version',
#  'X-B3-Flags',
#  'X-B3-ParentSpanId',
#  'X-B3-Sampled',
#  'X-B3-SpanId',
#  'X-B3-TraceId',
#  'X-Backdrop-Cache',
#  'X-Backside-Transport',
#  'X-CDN',
#  'X-CDN-Forward',
#  'X-CF1',
# ...

# %%
len(arr)
# Out:
# 185

# %%
url="https://www.amazon.in/HP-Athlon-15-6-inch-Silver-3050U-15s-gy0001au/dp/B08HJYFZ14/ref=sr_1_3?dchild=1&keywords=laptop&qid=1630631437&sr=8-3"

# %%
https://amazon.in

# %%
re.sub("^.*//|/.*|www\.","",str(url))
# Out:
# 'amazon.in'

# %%
regex="https://"+re.sub("^.*//|/.*|www\.","",str(url))

# %%
regex
# Out:
# 'https://amazon.in'

# %%
url="https://www.youtube.com/watch?v=vqCirjK61HI"

# %%
re.sub("^.*//|/.*|www\.","",url)
# Out:
# 'youtube.com'

# %%
regex="https://"+re.sub("^.*//|/.*|www\.","",url)

# %%
regex
# Out:
# 'https://youtube.com'

# %%
url="https://en.wikipedia.org/wiki/Avengers:_Endgame"

# %%
import re
regex="https://"+re.sub("^.*//|/.*|www\.","",url)

# %%
regex
# Out:
# 'https://en.wikipedia.org'

# %%
from bs4 import BeautifulSoup
import requests

# %%
url=requests

# %%
req=requests.get(regex)

# %%
req
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(req.content)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
req.headers
# Out:
# {'Date': 'Fri, 03 Sep 2021 03:52:50 GMT', 'Server': 'mw2385.codfw.wmnet', 'X-Content-Type-Options': 'nosniff', 'P3p': 'CP="See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'Content-Language': 'en', 'Vary': 'Accept-Encoding,Cookie,Authorization', 'Last-Modified': 'Fri, 03 Sep 2021 03:52:42 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Encoding': 'gzip', 'Age': '6696', 'X-Cache': 'cp5009 miss, cp5016 hit/33780', 'X-Cache-Status': 'hit-front', 'Server-Timing': 'cache;desc="hit-front", host;desc="cp5016"', 'Strict-Transport-Security': 'max-age=106384710; includeSubDomains; preload', 'Report-To': '{ "group": "wm_nel", "max_age": 86400, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'NEL': '{ "report_to": "wm_nel", "max_age": 86400, "failure_fraction": 0.05, "success_fraction": 0.0}', 'Permissions-Policy': 'interest-cohort=()', 
# ...

# %%
req.cookies.get_dict().keys()
# Out:
# dict_keys([])
