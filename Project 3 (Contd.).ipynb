# %% [markdown]
# #  Project 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
#     Steps:
#
#     1.Converting the JSON data into a DataFrame
#     2.Explore the data
#     3.Clean & manipulate the data
#     4.Analysis of Data
#     5.Conclusion

# %% [markdown]
# 1.Converting the JSON data into a DataFrame

# %% [markdown]
# JSON data url:"https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json"

# %%
df=pd.read_json("https://raw.githubusercontent.com/ozlerhakan/mongodb-json-files/master/datasets/books.json",lines=True)

# %%
df
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 0                            Unlocking Android     1933988673        416
# 1            Android in Action, Second Edition     1935182722        592
# 2                     Specification by Example     1617290084          0
# 3                             Flex 3 in Action     1933988746        576
# 4                             Flex 4 in Action     1935182420        600
# ...

# %% [markdown]
# 2.Data Exploration

# %%
#printing all the columns
df.columns
# Out:
# Index(['_id', 'title', 'isbn', 'pageCount', 'publishedDate', 'thumbnailUrl',
#        'shortDescription', 'longDescription', 'status', 'authors',
#        'categories'],
#       dtype='object')

# %%
df.shape
# Out:
# (431, 11)

# %%
#Total number of columns
df.shape[1]
# Out:
# 11

# %%
#statistical data 
df.describe()
# Out:
#          pageCount
# count   431.000000
# mean    289.259861
# std     260.873349
# min       0.000000
# 25%       0.000000
# 50%     350.000000
# 75%     475.000000
# max    1101.000000

# %%
#Total number of null values in each columns
df.isnull().sum()
# Out:
# _id                   0
# title                 0
# isbn                  3
# pageCount             0
# publishedDate        78
# thumbnailUrl         20
# shortDescription    271
# longDescription     168
# status                0
# authors               0
# categories            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   isbn              428 non-null    object
#  3   pageCount         431 non-null    int64
#  4   publishedDate     353 non-null    object
#  5   thumbnailUrl      411 non-null    object
#  6   shortDescription  160 non-null    object
#  7   longDescription   263 non-null    object
#  8   status            431 non-null    object
#  9   authors           431 non-null    object
#  10  categories        431 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 37.2+ KB

# %% [markdown]
# 3. Data Cleaning

# %%
df.head()
# Out:
#   _id                              title        isbn  pageCount  \
# 0   1                  Unlocking Android  1933988673        416
# 1   2  Android in Action, Second Edition  1935182722        592
# 2   3           Specification by Example  1617290084          0
# 3   4                   Flex 3 in Action  1933988746        576
# 4   5                   Flex 4 in Action  1935182420        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
df.tail()
# Out:
#                                       _id  \
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 426                             DSLs in Action     1935182455        376
# 427  Database Programming for Handheld Devices     1884777856          0
# 428           Jakarta Commons Online Bookshelf     1932394524        402
# 429                   Browsing with HttpClient  1932394524a-e          0
# 430               Codec: Encoders and Decoders  1932394524j-e          0
#
#                                  publishedDate  \
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# ...

# %%
#Clean the ISBN number

# %%
str(df.isbn)
# Out:
# '0         1933988673\n1         1935182722\n2         1617290084\n3         1933988746\n4         1935182420\n           ...      \n426       1935182455\n427       1884777856\n428       1932394524\n429    1932394524a-e\n430    1932394524j-e\nName: isbn, Length: 431, dtype: object'

# %%
df
# Out:
#                                       _id  \
# 0                                       1
# 1                                       2
# 2                                       3
# 3                                       4
# 4                                       5
# ..                                    ...
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title           isbn  pageCount  \
# 0                            Unlocking Android   1933988673.0        416
# 1            Android in Action, Second Edition   1935182722.0        592
# 2                     Specification by Example   1617290084.0          0
# 3                             Flex 3 in Action   1933988746.0        576
# 4                             Flex 4 in Action   1935182420.0        600
# ...

# %%
#list all those rows in the isbn column where the isbn value is null

df[df.isbn.isna()]      #OR
#df[df.isbn.isnull()]    #OR
# df[df.isbn.isnull()==True]
# Out:
#      _id                                          title isbn  pageCount  \
# 21    23          Hibernate in Action (Chinese Edition)  NaN        400
# 98   148                    Portlets and Apache Portals  NaN        500
# 358  707  Secrets of the JavaScript Ninja pBook upgrade  NaN          0
#
#                                  publishedDate  \
# 21   {'$date': '1999-06-01T00:00:00.000-0700'}
# 98   {'$date': '2005-10-01T00:00:00.000-0700'}
# 358                                        NaN
#
#                                           thumbnailUrl  \
# 21   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 98   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 358                                                NaN
#
#                                       shortDescription  \
# 21                                                 NaN
# 98   Portlets and Apache Portals was not published ...
# 358                                                NaN
#
# ...

# %%
#Dropping off the columns 'isbn'
df.drop('isbn',axis=1,inplace=True)

# %%
df.head()
# Out:
#   _id                              title  pageCount  \
# 0   1                  Unlocking Android        416
# 1   2  Android in Action, Second Edition        592
# 2   3           Specification by Example          0
# 3   4                   Flex 3 in Action        576
# 4   5                   Flex 4 in Action        600
#
#                                publishedDate  \
# 0  {'$date': '2009-04-01T00:00:00.000-0700'}
# 1  {'$date': '2011-01-14T00:00:00.000-0800'}
# 2  {'$date': '2011-06-03T00:00:00.000-0700'}
# 3  {'$date': '2009-02-02T00:00:00.000-0800'}
# 4  {'$date': '2010-11-15T00:00:00.000-0800'}
#
#                                         thumbnailUrl  \
# 0  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 1  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 2  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 3  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 4  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
# ...

# %%
df.tail()
# Out:
#                                       _id  \
# 426  {'$oid': '53c2ae8528d75d572c06adb8'}
# 427  {'$oid': '53c2ae8528d75d572c06adb9'}
# 428  {'$oid': '53c2ae8528d75d572c06adba'}
# 429  {'$oid': '53c2ae8528d75d572c06adbb'}
# 430  {'$oid': '53c2ae8528d75d572c06adbc'}
#
#                                          title  pageCount  \
# 426                             DSLs in Action        376
# 427  Database Programming for Handheld Devices          0
# 428           Jakarta Commons Online Bookshelf        402
# 429                   Browsing with HttpClient          0
# 430               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 426  {'$date': '2010-12-01T00:00:00.000-0800'}
# 427  {'$date': '2000-07-01T00:00:00.000-0700'}
# 428  {'$date': '2005-03-01T00:00:00.000-0800'}
# 429  {'$date': '2005-03-01T00:00:00.000-0800'}
# 430  {'$date': '2005-03-01T00:00:00.000-0800'}
#
#                                           thumbnailUrl  \
# ...

# %%
df.title
# Out:
# 0                              Unlocking Android
# 1              Android in Action, Second Edition
# 2                       Specification by Example
# 3                               Flex 3 in Action
# 4                               Flex 4 in Action
#                          ...
# 426                               DSLs in Action
# 427    Database Programming for Handheld Devices
# 428             Jakarta Commons Online Bookshelf
# 429                     Browsing with HttpClient
# 430                 Codec: Encoders and Decoders
# Name: title, Length: 431, dtype: object

# %%
# When you want to watch all the title values without these ...
df.title.unique()   #<- This will show all the title values but this unique will be shown name only once,though it occurs many times
# Out:
# array(['Unlocking Android', 'Android in Action, Second Edition',
#        'Specification by Example', 'Flex 3 in Action', 'Flex 4 in Action',
#        'Collective Intelligence in Action', 'Zend Framework in Action',
#        'Flex on Java', 'Griffon in Action', 'OSGi in Depth',
#        'Flexible Rails', 'Hello! Flex 4', 'Coffeehouse',
#        'Team Foundation Server 2008 in Action',
#        'Brownfield Application Development in .NET', 'MongoDB in Action',
#        'Distributed Application Development with PowerBuilder 6.0',
#        'Jaguar Development with PowerBuilder 7', 'Taming Jaguar',
#        '3D User Interfaces with Java 3D', 'Hibernate in Action',
#        'Hibernate in Action (Chinese Edition)',
#        'Java Persistence with Hibernate', 'JSTL in Action',
#        'iBATIS in Action', 'Designing Hard Software',
#        'Hibernate Search in Action', 'jQuery in Action',
#        'jQuery in Action, Second Edition',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431 entries, 0 to 430
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               431 non-null    object
#  1   title             431 non-null    object
#  2   pageCount         431 non-null    int64
#  3   publishedDate     353 non-null    object
#  4   thumbnailUrl      411 non-null    object
#  5   shortDescription  160 non-null    object
#  6   longDescription   263 non-null    object
#  7   status            431 non-null    object
#  8   authors           431 non-null    object
#  9   categories        431 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 33.8+ KB

# %%
#the total number of title which are unique
len(df.title.unique())
# Out:
# 427

# %%
#show the duplicated rows w.r.t. the title
df[df.title.duplicated()]   #or
# df[df.duplicated('title')]
# Out:
#      _id                                   title  pageCount  \
# 113  165                     Android in Practice          0
# 175  231               SQL Server MVP Deep Dives        848
# 176  232               SQL Server MVP Deep Dives        848
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 113                                        NaN
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 113  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 113                                                NaN
# ...

# %%
df[df.title=="Jaguar Development with PowerBuilder 7"]
# Out:
#      _id                                   title  pageCount  \
# 17    19  Jaguar Development with PowerBuilder 7        550
# 325  656  Jaguar Development with PowerBuilder 7          0
#
#                                  publishedDate  \
# 17   {'$date': '1999-08-01T00:00:00.000-0700'}
# 325  {'$date': '1999-08-09T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 17   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 325                                                NaN
#
#                                       shortDescription  \
# 17   Jaguar Development with PowerBuilder 7 is the ...
# 325                                                NaN
#
#                                        longDescription   status  \
# 17   Jaguar Development with PowerBuilder 7 is the ...  PUBLISH
# 325                                                NaN  PUBLISH
#
#                 authors                     categories
# ...

# %%
df[df.title=="SQL Server MVP Deep Dives"]
# Out:
#      _id                      title  pageCount  \
# 174  230  SQL Server MVP Deep Dives        848
# 175  231  SQL Server MVP Deep Dives        848
# 176  232  SQL Server MVP Deep Dives        848
#
#                                  publishedDate  \
# 174  {'$date': '2009-11-01T00:00:00.000-0700'}
# 175  {'$date': '2009-11-15T00:00:00.000-0800'}
# 176  {'$date': '2009-11-01T00:00:00.000-0700'}
#
#                                           thumbnailUrl  \
# 174  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 175  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 176  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 174  SQL Server MVP Deep Dives is organized into fi...
# 175  SQL Server MVP Deep Dives is organized into fi...
# 176                                                NaN
#
#                                        longDescription   status  \
# ...

# %%
df[df.title=="Android in Practice"]
# Out:
#      _id                title  pageCount  \
# 47    54  Android in Practice        500
# 113  165  Android in Practice          0
#
#                                  publishedDate  \
# 47   {'$date': '2011-09-30T00:00:00.000-0700'}
# 113                                        NaN
#
#                                           thumbnailUrl  \
# 47   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# 113  https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
#
#                                       shortDescription  \
# 47   Android in Practice is treasure trove of Andro...
# 113                                                NaN
#
#                                        longDescription   status  \
# 47   Android, Google's platform for mobile applicat...  PUBLISH
# 113                                                NaN     MEAP
#
#                                                authors           categories
# 47   [Charlie Collins, Michael D. Galpin, , Matthia...  [Mobile Technology]
# ...

# %%
#delete the row data with same title name
df.drop_duplicates('title',inplace=True)

# %%
df[df.duplicated('title')]
# Out:
# Empty DataFrame
# Columns: [_id, title, pageCount, publishedDate, thumbnailUrl, shortDescription, longDescription, status, authors, categories]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 430
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    object
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 36.7+ KB

# %%
# Rearrnge the values of the _id columns

df['_id']=np.arange(1,len(df._id)+1)
         #OR

# for i in range(1,len(df._id)+1):
#     df._id[i-1]=i

# %%
df
# Out:
#      _id                                      title  pageCount  \
# 0      1                          Unlocking Android        416
# 1      2          Android in Action, Second Edition        592
# 2      3                   Specification by Example          0
# 3      4                           Flex 3 in Action        576
# 4      5                           Flex 4 in Action        600
# ..   ...                                        ...        ...
# 426  423                             DSLs in Action        376
# 427  424  Database Programming for Handheld Devices          0
# 428  425           Jakarta Commons Online Bookshelf        402
# 429  426                   Browsing with HttpClient          0
# 430  427               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 430
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 35.0+ KB

# %%
#Reindexing
df.index=np.arange(0,len(df))

#or
# df=df.reset_index(drop=True)

# %%
df
# Out:
#      _id                                      title  pageCount  \
# 0      1                          Unlocking Android        416
# 1      2          Android in Action, Second Edition        592
# 2      3                   Specification by Example          0
# 3      4                           Flex 3 in Action        576
# 4      5                           Flex 4 in Action        600
# ..   ...                                        ...        ...
# 422  423                             DSLs in Action        376
# 423  424  Database Programming for Handheld Devices          0
# 424  425           Jakarta Commons Online Bookshelf        402
# 425  426                   Browsing with HttpClient          0
# 426  427               Codec: Encoders and Decoders          0
#
#                                  publishedDate  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             423 non-null    object
#  2   pageCount         423 non-null    float64
#  3   publishedDate     346 non-null    object
#  4   thumbnailUrl      404 non-null    object
#  5   shortDescription  158 non-null    object
#  6   longDescription   261 non-null    object
#  7   status            423 non-null    object
#  8   authors           423 non-null    object
#  9   categories        423 non-null    object
# dtypes: float64(1), int32(1), object(8)
# memory usage: 35.0+ KB

# %%
mean=round(np.mean(df.pageCount))  #OR   round(df.pageCount.mean())  <- This will round off the data

# %%
mean
# Out:
# 288

# %%
#Replace the values in the pageCount column where the value == 0 with the mean (rounded off & dtype) of pagecount column
df["pageCount"]=df["pageCount"].replace(0,mean)

# %%
df.rename(columns={"publishedDate":"publishedYear"})
# Out:
#      _id                                      title  pageCount  \
# 0      1                          Unlocking Android        416
# 1      2          Android in Action, Second Edition        592
# 2      3                   Specification by Example        288
# 3      4                           Flex 3 in Action        576
# 4      5                           Flex 4 in Action        600
# ..   ...                                        ...        ...
# 422  423                             DSLs in Action        376
# 423  424  Database Programming for Handheld Devices        288
# 424  425           Jakarta Commons Online Bookshelf        402
# 425  426                   Browsing with HttpClient        288
# 426  427               Codec: Encoders and Decoders        288
#
#                                  publishedYear  \
# 0    {'$date': '2009-04-01T00:00:00.000-0700'}
# 1    {'$date': '2011-01-14T00:00:00.000-0800'}
# 2    {'$date': '2011-06-03T00:00:00.000-0700'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedDate     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 35.0+ KB

# %%
data=df.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedYear     350 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 51.2+ KB

# %%
data.rename(columns={"publishedDate":"publishedYear"},inplace=True)

# %%
data[data.publishedYear.isna()]
# Out:
#      _id                                title  pageCount publishedYear  \
# 96    97          Distributed Agile in Action        325           NaN
# 120  121     Groovy in Action, Second Edition        700           NaN
# 134  135                         F# in Action        425           NaN
# 234  235          C# in Depth, Second Edition        584           NaN
# 266  267                     The Engaging Web        325           NaN
# ..   ...                                  ...        ...           ...
# 390  391  Practical Probabilistic Programming        288           NaN
# 391  392                      Unity in Action        288           NaN
# 392  393                 Express.js in Action        288           NaN
# 393  394      Learn Git in a Month of Lunches        288           NaN
# 394  395                   Understanding SPAs        288           NaN
#
#                                           thumbnailUrl  \
# 96   https://s3.amazonaws.com/AKIAJC5RLADLUMVRPFDQ....
# ...

# %%
data.publishedYear.isna().sum()
# Out:
# 77

# %%
data.publishedYear.fillna(0,inplace=True)

# %%
re.sub("^.*: '|-.*}","",str(data.publishedYear[0]))
# Out:
# '2009'

# %%
for i in range(len(data.publishedYear)):
    data.publishedYear[i]=re.sub("^.*: '|-.*}|","",str(data.publishedYear[i]))
# Out:
# <ipython-input-237-733493a5ce4b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.publishedYear[i]=re.sub("^.*: '|-.*}|","",str(data.publishedYear[i]))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedYear     427 non-null    object
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(1), int64(1), object(8)
# memory usage: 51.2+ KB

# %%
data.publishedYear=data.publishedYear.astype(int)  #<- This will convert it into the int

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               427 non-null    int32
#  1   title             427 non-null    object
#  2   pageCount         427 non-null    int64
#  3   publishedYear     427 non-null    int32
#  4   thumbnailUrl      408 non-null    object
#  5   shortDescription  159 non-null    object
#  6   longDescription   262 non-null    object
#  7   status            427 non-null    object
#  8   authors           427 non-null    object
#  9   categories        427 non-null    object
# dtypes: int32(2), int64(1), object(7)
# memory usage: 49.5+ KB

# %%
m=round(data.publishedYear.mean())

# %%
data.publishedYear=data.publishedYear.replace(0,m)

# %%
data.drop(["thumbnailUrl","shortDescription","longDescription"],axis=1,inplace=True)

# %%
data
# Out:
#      _id                                      title  pageCount  publishedYear  \
# 0      1                          Unlocking Android        416           2009
# 1      2          Android in Action, Second Edition        592           2011
# 2      3                   Specification by Example        288           2011
# 3      4                           Flex 3 in Action        576           2009
# 4      5                           Flex 4 in Action        600           2010
# ..   ...                                        ...        ...            ...
# 422  423                             DSLs in Action        376           2010
# 423  424  Database Programming for Handheld Devices        288           2000
# 424  425           Jakarta Commons Online Bookshelf        402           2005
# 425  426                   Browsing with HttpClient        288           2005
# 426  427               Codec: Encoders and Decoders        288           2005
#
# ...

# %%
data.status.unique()
# Out:
# array(['PUBLISH', 'MEAP'], dtype=object)

# %%
sum(data.status=="PUBLISH")   #<- It will show how many are "PUBLISH" inside the dataframe
# Out:
# 360

# %%
sum(data.status=="MEAP")      #<- It will show how many are "MEAP" inside the dataframe
# Out:
# 67

# %%
#It will directly show the total numbersof both values
data["status"].value_counts()
# Out:
# PUBLISH    360
# MEAP        67
# Name: status, dtype: int64

# %%
#MEAP to UNPUBLISH
data.status=data.status.replace("MEAP","UNPUBLISH")

# %%
data["status"].value_counts()
# Out:
# PUBLISH      360
# UNPUBLISH     67
# Name: status, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427 entries, 0 to 426
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   _id            427 non-null    int32
#  1   title          427 non-null    object
#  2   pageCount      427 non-null    int64
#  3   publishedYear  427 non-null    int32
#  4   status         427 non-null    object
#  5   authors        427 non-null    object
#  6   categories     427 non-null    object
# dtypes: int32(2), int64(1), object(4)
# memory usage: 39.5+ KB

# %%
data.authors.value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# []                    37
# [Vikram Goyal]        12
# [Ted Neward]           3
# [Jon Skeet]            3
# [Tim Hatton]           3
#                       ..
# [Kyle Banker]          1
# [Robert Kabacoff]      1
# [Shawn Bayern]         1
# [Chuck Lam]            1
# [Anthony Williams]     1
# Name: authors, Length: 348, dtype: int64

# %%
#drop _id,authors,categories columns
data.drop(["_id","authors"],axis=1,inplace=True)

# %%
data.drop(["categories"],axis=1,inplace=True)

# %%
data
# Out:
#                                          title  pageCount  publishedYear  \
# 0                            Unlocking Android        416           2009
# 1            Android in Action, Second Edition        592           2011
# 2                     Specification by Example        288           2011
# 3                             Flex 3 in Action        576           2009
# 4                             Flex 4 in Action        600           2010
# ..                                         ...        ...            ...
# 422                             DSLs in Action        376           2010
# 423  Database Programming for Handheld Devices        288           2000
# 424           Jakarta Commons Online Bookshelf        402           2005
# 425                   Browsing with HttpClient        288           2005
# 426               Codec: Encoders and Decoders        288           2005
#
#       status
# 0    PUBLISH
# 1    PUBLISH
# 2    PUBLISH
# 3    PUBLISH
# 4    PUBLISH
# ...

# %% [markdown]
# Data Analysis

# %%
data.head()
# Out:
#                                title  pageCount  publishedYear   status
# 0                  Unlocking Android        416           2009  PUBLISH
# 1  Android in Action, Second Edition        592           2011  PUBLISH
# 2           Specification by Example        288           2011  PUBLISH
# 3                   Flex 3 in Action        576           2009  PUBLISH
# 4                   Flex 4 in Action        600           2010  PUBLISH

# %%
#plot a graph to show all the counts of the categories in the status column

# %%
data["status"].value_counts().plot.bar(figsize=(10,5))
plt.grid()

# %%
data['publishedYear'].value_counts()
# Out:
# 1645    77
# 2011    38
# 2013    31
# 2012    31
# 2009    25
# 2002    23
# 2005    23
# 2010    21
# 2008    19
# 2014    16
# 2003    15
# 2007    14
# 1999    13
# 1997    13
# 2004    13
# 1998    12
# 2006    11
# 2000    10
# 1996     9
# 1995     7
# 2001     5
# 1993     1
# Name: publishedYear, dtype: int64

# %%
low=1645
high=2014
make a hestogram in range of 
1600-1700
1700-1800
1900-2000
2000-2100

# %%
x=data.publishedYear.value_counts()
plot.hist(x,bins=5)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# list out top 10 books that has the highest number of pages
data.sort_values(by="pageCount",ascending=False).head(10)
# Out:
#                                                  title  pageCount  \
# 60   Essential Guide to Peoplesoft Development and ...       1101
# 251                      Ten Years of UserFriendly.Org       1096
# 68                             Java Foundation Classes       1088
# 397                            Windows Forms in Action        950
# 189                            Silverlight 5 in Action        925
# 211                               Swing Second Edition        912
# 408                Dynamic WAP Application Development        888
# 22                     Java Persistence with Hibernate        880
# 102           Java Network Programming, Second Edition        860
# 173                          SQL Server MVP Deep Dives        848
#
#      publishedYear   status
# 60            2000  PUBLISH
# 251           2008  PUBLISH
# 68            2001  PUBLISH
# 397           2006  PUBLISH
# 189           2012  PUBLISH
# 211           2003  PUBLISH
# 408           2002  PUBLISH
# ...

# %%
data.head(10)
# Out:
#                                title  pageCount  publishedYear   status
# 0                  Unlocking Android        416           2009  PUBLISH
# 1  Android in Action, Second Edition        592           2011  PUBLISH
# 2           Specification by Example        288           2011  PUBLISH
# 3                   Flex 3 in Action        576           2009  PUBLISH
# 4                   Flex 4 in Action        600           2010  PUBLISH
# 5  Collective Intelligence in Action        425           2008  PUBLISH
# 6           Zend Framework in Action        432           2008  PUBLISH
# 7                       Flex on Java        265           2010  PUBLISH
# 8                  Griffon in Action        375           2012  PUBLISH
# 9                      OSGi in Depth        325           2011  PUBLISH

# %%
plt.bar(data.title.head(10),data.pageCount.head(10))
# Out:
# <BarContainer object of 10 artists>

# %%
#For information
# Change the dtype of the pageCount to int64 
# df=df.astype({"pageCount":"int64"})

# astype <- This will convert the column in which dtype you want
